# %% [markdown]
# <a href="https://colab.research.google.com/github/tawfiqahmad88/Ayrik-Sistemler-Icin-Ileri-Olasilik-devi-01/blob/main/Kesikli_Olas%C4%B1l%C4%B1k_Fonksiyonlar%C4%B1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Kesikli Olasılık Fonksiyonları**

# %% [markdown]
# # **örnek**
#
# Rastgele seçilmiş bir Türk çocuğunun okula giden bir günlük konuşma yapabileceği dil sayısı olarak tanımlanan X rastgele değişkenini düşünün.
# 1000 Türk okul çocuğundan rastgele bir örneklem aldığımızı ve konuşulan dil sayısı için aşağıdaki verileri elde ettiğimizi varsayalım.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ardından, göreceli frekanslardan X'in pf'si olan bir pX (x) tahmini elde ederiz.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Dolayısıyla, Türkiye'de okul çağındaki çocukların %22,6'sının (tam olarak) iki dilde günlük konuşmalar yapabildiğini tahmin ediyoruz; eşdeğer olarak, Pr(X = 2) = 0.226 olduğunu tahmin ediyoruz.
# Bu durumda x = 7'nin (örneğin) imkansız bir değer olduğundan emin olamayız. Olabilir
# sadece o kadar nadir olun ki örnekte ortaya çıkmadı
